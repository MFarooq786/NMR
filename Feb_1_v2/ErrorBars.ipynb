# %%
import matplotlib.pyplot as plt

# Data points
y = [48.9399, 57.0213, 75.6845, 84.7842]

# Errors for each data point
yerr = [0.1499, 0.2833, 1.7854, 3.2365]

# X values (assuming sequential for demonstration)
x = range(1, len(y)+1)

# Create the error bar plot
plt.errorbar(x, y, yerr=yerr, fmt='o', ecolor='orangered', capsize=5, linestyle='None', marker='s', markersize=5, color='skyblue')

# Add labels and title for clarity
plt.xlabel('Data Point')
plt.ylabel('T1z Extracted Value')
#plt.title('Error Bar Plot of Data Points')
plt.savefig('Error.pdf',dpi=2000)
# Show the plot
plt.show()
# Out:
# /var/folders/tc/v8h_rk3n2bj391gqqp5xkdl00000gn/T/ipykernel_6570/324734225.py:13: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.errorbar(x, y, yerr=yerr, fmt='o', ecolor='orangered', capsize=5, linestyle='None', marker='s', markersize=5, color='skyblue')
